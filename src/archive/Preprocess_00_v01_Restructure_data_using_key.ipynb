# %% [markdown]
# # Restructure data using key
#
# This code processes images, provided by class in seperate folders, by two institutes (CEFAS & WMR). The images in the folders are moved to new folders, sometimes merged, following a csv file (the "key" file) provided by the researchers.

# %%
# import modules

import pandas as pd
import os
import shutil
from pathlib import Path

# %%
# Read the CSV file
df = pd.read_csv("data/DETAILED_key.csv")
df.head()
# Out:
#                   folder              detailed_cat Source  \
# 0  amphipoda_caprellidae       Crustacea_Amphipoda  CEFAS
# 1         appendicularia                  Larvacea  CEFAS
# 2        bivalvia_larvae  Mollusca_Bivalvia-larvae  CEFAS
# 3     brachiopoda_larvae        Brachiopoda-larvae  CEFAS
# 4     branchiostomatidae        Branchiostomatidae  CEFAS
#
#                    check  check2
# 0  amphipoda_caprellidae       1
# 1         appendicularia       1
# 2        bivalvia_larvae       1
# 3     brachiopoda_larvae       1
# 4     branchiostomatidae       1

# %%
# Define the path for the merged folder inside the 'data' directory
merged_dir = Path("data") / "DETAILED_merged"

# Create the directories if they don't exist
merged_dir.mkdir(parents=True, exist_ok=True)

print(f"'merged' folder created at: {merged_dir.resolve()}")
# Out:
# 'merged' folder created at: /lustre/backup/WUR/WMR/hoeke007/Project003c_Plankton_imager_03/data/DETAILED_merged

# %%
# OPTIONAL: Delete folder

## Check if it exists, then delete
#if merged_dir.exists():
#    shutil.rmtree(merged_dir)
#    print(f"Deleted folder: {merged_dir.resolve()}")
#else:
#    print(f"Folder not found: {merged_dir.resolve()}")

# %%
# %%time

# Loop through each row in the DataFrame
for idx, row in df.iterrows():
    # Get the source base path and folder name
    source_base = Path(row["Source"])
    folder_name = row["folder"]
    category = row["detailed_cat"]

    # Full path to the source folder: Source/folder
    source_folder = "data" / source_base / folder_name

    # Full destination path: data/DETAILED_merged/detailed_cat
    dest_folder = Path("data") / "DETAILED_merged" / category

    # Create destination folder if it doesn't exist
    dest_folder.mkdir(parents=True, exist_ok=True)

    # Check if the source folder exists before attempting to copy
    if not source_folder.exists():
        print(f"❌ Source folder does not exist: {source_folder}")
        continue  # Skip this row if the source doesn't exist

    # Iterate over the contents of the source folder
    for item in source_folder.iterdir():
        # Destination path for the current item
        dest_path = dest_folder / item.name

        # If a file or folder with the same name already exists in destination
        if dest_path.exists():
            print(f"⚠️ File already exists, skipping: {dest_path}")
        else:
            # Copy folders (recursively) or files accordingly
            if item.is_dir():
                shutil.copytree(item, dest_path)
            else:
                shutil.copy2(item, dest_path)

    print(f"✅ Finished copying contents from {source_folder} to {dest_folder}")
# Out:
# ✅ Finished copying contents from data/CEFAS/amphipoda_caprellidae to data/DETAILED_merged/Crustacea_Amphipoda
# ✅ Finished copying contents from data/CEFAS/appendicularia to data/DETAILED_merged/Larvacea
# ✅ Finished copying contents from data/CEFAS/bivalvia_larvae to data/DETAILED_merged/Mollusca_Bivalvia-larvae
# ✅ Finished copying contents from data/CEFAS/brachiopoda_larvae to data/DETAILED_merged/Brachiopoda-larvae
# ✅ Finished copying contents from data/CEFAS/branchiostomatidae to data/DETAILED_merged/Branchiostomatidae
# ✅ Finished copying contents from data/CEFAS/chaetognatha to data/DETAILED_merged/Chaetognatha
# ✅ Finished copying contents from data/CEFAS/ciliophora_suctoria to data/DETAILED_merged/Ciliophora
# ✅ Finished copying contents from data/CEFAS/cirripedia_barnacle_cyprid to data/DETAILED_merged/Crustacea_Cirripedia-larvae
# ✅ Finished copying contents from data/CEFAS/cnidaria_hydrozoa_polyp to data/DETAILED_merged/Cnidaria_Hydrozoa-polyp
# ✅ Finished copying contents from data/CEFAS/cnidaria_hydrozoa-hydromedusa to data/DETAILED_merged/Cnidaria_Hydrozoa-medusa
# ✅ Finished copying contents from data/CEFAS/copepod_calanoida_acartia-spp to data/DETAILED_merged/Crustacea_Copepoda_Calanoida
# ✅ Finished copying contents from data/CEFAS/copepod_calanoida_calanus-spp to data/DETAILED_merged/Crustacea_Copepoda_Calanoida
# ✅ Finished copying contents from data/CEFAS/copepod_calanoida_centropages-spp to data/DETAILED_merged/Crustacea_Copepoda_Calanoida
# ✅ Finished copying contents from data/CEFAS/copepod_calanoida_temora-spp to data/DETAILED_merged/Crustacea_Copepoda_Calanoida
# ✅ Finished copying contents from data/CEFAS/copepod_cyclopoida_oithona-spp to data/DETAILED_merged/Crustacea_Copepoda_Cyclopoida
# ✅ Finished copying contents from data/CEFAS/copepod_cyclopoida_oncaea-spp to data/DETAILED_merged/Crustacea_Copepoda_Cyclopoida
# ✅ Finished copying contents from data/CEFAS/copepod_harpacticoida_euterpina to data/DETAILED_merged/Crustacea_Copepoda_Harpacticoida
# ✅ Finished copying contents from data/CEFAS/copepod_harpacticoida_microstella to data/DETAILED_merged/Crustacea_Copepoda_Harpacticoida
# ✅ Finished copying contents from data/CEFAS/copepod_moults to data/DETAILED_merged/Crustacea-exuvia
# ✅ Finished copying contents from data/CEFAS/copepod_nauplii to data/DETAILED_merged/Crustacea_Copepoda-nauplii
# ✅ Finished copying contents from data/CEFAS/decapoda-larvae_brachyura to data/DETAILED_merged/Crustacea_Decapoda-larvae
# ✅ Finished copying contents from data/CEFAS/detritus to data/DETAILED_merged/Detritus
# ✅ Finished copying contents from data/CEFAS/echniodermata-larvae to data/DETAILED_merged/exclude
# ✅ Finished copying contents from data/CEFAS/euphausiid_nauplii to data/DETAILED_merged/Crustacea_Euphausidae
# ✅ Finished copying contents from data/CEFAS/fish-larvae_clupeidae to data/DETAILED_merged/Fish-larvae
# ✅ Finished copying contents from data/CEFAS/gastropoda to data/DETAILED_merged/Mollusca_Gastropoda
# ✅ Finished copying contents from data/CEFAS/invertabrate_eggs to data/DETAILED_merged/Invertebrata-eggs
# ✅ Finished copying contents from data/CEFAS/nt-bubbles to data/DETAILED_merged/bubbles
# ✅ Finished copying contents from data/CEFAS/Phyto_Centrics to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Chaetoceros to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Coscinodiscus to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Guinardia-flaccida to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Lauderia to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Noctiluca to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Odontella to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Pleurosigmataceae to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Proboscia-truncata to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Protoperidinium to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Rhizosolenia to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Thalassiosira to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Triceratium to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Trigonium-alternans to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos-lineatus to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos-macroceros group to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos-platycorne to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos-tripos group to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/CEFAS/Podon to data/DETAILED_merged/Crustacea_Cladocera
# ✅ Finished copying contents from data/CEFAS/radiolaria to data/DETAILED_merged/Radiozoa
# ✅ Finished copying contents from data/CEFAS/tintinnida to data/DETAILED_merged/Ciliophora
# ✅ Finished copying contents from data/WMR/amphioxus-larva to data/DETAILED_merged/Branchiostomatidae
# ✅ Finished copying contents from data/WMR/artefact_cleaning_fibre to data/DETAILED_merged/artefacts
# ✅ Finished copying contents from data/WMR/artefact_long_line to data/DETAILED_merged/artefacts
# ✅ Finished copying contents from data/WMR/balanoid-cypris to data/DETAILED_merged/Crustacea_Cirripedia-larvae
# ✅ Finished copying contents from data/WMR/balanoid-nauplius to data/DETAILED_merged/Crustacea_Cirripedia-larvae
# ✅ Finished copying contents from data/WMR/bryozoa-cyphonautes to data/DETAILED_merged/Bryozoa-larvae
# ✅ Finished copying contents from data/WMR/bubbles to data/DETAILED_merged/bubbles
# ✅ Finished copying contents from data/WMR/chaetognath to data/DETAILED_merged/Chaetognatha
# ✅ Finished copying contents from data/WMR/chordata_tunicata-tadpole_larva to data/DETAILED_merged/Tunicata_Ascidiacea-larvae
# ✅ Finished copying contents from data/WMR/cladocera_evadne to data/DETAILED_merged/Crustacea_Cladocera
# ✅ Finished copying contents from data/WMR/cladocera_penilia to data/DETAILED_merged/Crustacea_Cladocera
# ✅ Finished copying contents from data/WMR/cladocera_podon_pleopis to data/DETAILED_merged/Crustacea_Cladocera
# ✅ Finished copying contents from data/WMR/cnidaria_hydrozoa_siphonophora to data/DETAILED_merged/Cnidaria_Hydrozoa_Siphonophora
# ✅ Finished copying contents from data/WMR/cnidaria_hydrozoa-hydromedusa to data/DETAILED_merged/Cnidaria_Hydrozoa-medusa
# ✅ Finished copying contents from data/WMR/cnidaria_hydrozoa-hydropolyp to data/DETAILED_merged/Cnidaria_Hydrozoa-polyp
# ✅ Finished copying contents from data/WMR/cnidaria_scyphozoa-ephyrae to data/DETAILED_merged/Cnidaria_Scyphozoa-ephyrae
# ✅ Finished copying contents from data/WMR/cnidaria-tentacle to data/DETAILED_merged/exclude
# ✅ Finished copying contents from data/WMR/crustacea_amphipoda to data/DETAILED_merged/Crustacea_Amphipoda
# ✅ Finished copying contents from data/WMR/crustacea_caprella to data/DETAILED_merged/Crustacea_Amphipoda
# ✅ Finished copying contents from data/WMR/crustacea_copepoda to data/DETAILED_merged/exclude
# ✅ Finished copying contents from data/WMR/crustacea_copepoda_monstrilloidae to data/DETAILED_merged/Crustacea_Copepoda_Monstrilloidae
# ✅ Finished copying contents from data/WMR/crustacea_copepoda_nauplii to data/DETAILED_merged/Crustacea_Copepoda-nauplii
# ✅ Finished copying contents from data/WMR/crustacea_copepoda-epibionts to data/DETAILED_merged/exclude
# ✅ Finished copying contents from data/WMR/crustacea_megalopa to data/DETAILED_merged/Crustacea_Decapoda-larvae
# ✅ Finished copying contents from data/WMR/crustacea_mysida to data/DETAILED_merged/Crustacea_Mysidacea
# ✅ Finished copying contents from data/WMR/crustacea_porcellanidae-zoea to data/DETAILED_merged/Crustacea_Decapoda-larvae
# ✅ Finished copying contents from data/WMR/crustacea-exuvium to data/DETAILED_merged/Crustacea-exuvia
# ✅ Finished copying contents from data/WMR/crustacea-zoea_crab to data/DETAILED_merged/Crustacea_Decapoda-larvae
# ✅ Finished copying contents from data/WMR/crustacea-zoea_shrimp to data/DETAILED_merged/Crustacea_Decapoda-larvae
# ✅ Finished copying contents from data/WMR/ctenophora to data/DETAILED_merged/Ctenophora
# ✅ Finished copying contents from data/WMR/cumacea to data/DETAILED_merged/Crustacea_Cumacea
# ✅ Finished copying contents from data/WMR/cyanobacteria_trichodesmium to data/DETAILED_merged/Cyanobacteria
# ✅ Finished copying contents from data/WMR/detritus to data/DETAILED_merged/Detritus
# ✅ Finished copying contents from data/WMR/diatom_odontella to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/WMR/diatom-loop to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/WMR/diatom-other to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/WMR/diatom-setae to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/WMR/diatom-solitary_centric to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/WMR/diatom-straight to data/DETAILED_merged/Heterokontophyta_Bacillariophyceae
# ✅ Finished copying contents from data/WMR/dinoflagellate_noctiluca-fragment to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/WMR/dinoflagellate_noctiluca-intact to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/WMR/dinoflagellate_pyrocystis to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/WMR/dinoflagellate_Tripos to data/DETAILED_merged/Myzozoa_Dinophyceae
# ✅ Finished copying contents from data/WMR/echinodermata_asteroidea_Luidia-Branchiolaria to data/DETAILED_merged/Echinodermata_Asteroida-larvae
# ✅ Finished copying contents from data/WMR/echinodermata-echinopluteus_type_3 to data/DETAILED_merged/Echinodermata_Echinoidea-larvae
# ✅ Finished copying contents from data/WMR/echinodermata-ophiopluteus_type_2 to data/DETAILED_merged/Echinodermata_Ophiuroidea-larvae
# ✅ Finished copying contents from data/WMR/echinoderm-bipinnaria to data/DETAILED_merged/Echinodermata_Asteroida-larvae
# ✅ Finished copying contents from data/WMR/echinoderm-branchiolaria to data/DETAILED_merged/Echinodermata_Asteroida-larvae
# ✅ Finished copying contents from data/WMR/echinoderm-echinopluteus_type_1 to data/DETAILED_merged/Echinodermata_Echinoidea-larvae
# ✅ Finished copying contents from data/WMR/echinoderm-echinopluteus_type_2 to data/DETAILED_merged/Echinodermata_Echinoidea-larvae
# ✅ Finished copying contents from data/WMR/echinoderm-ophiopluteus_type_1 to data/DETAILED_merged/Echinodermata_Ophiuroidea-larvae
# ✅ Finished copying contents from data/WMR/echinoderm-stars_asteridae to data/DETAILED_merged/Echinodermata_Asteroida-larvae
# ✅ Finished copying contents from data/WMR/echinoderm-stars_echino to data/DETAILED_merged/Echinodermata_Echinoidea-larvae
# ✅ Finished copying contents from data/WMR/echinoderm-stars_ophio to data/DETAILED_merged/Echinodermata_Ophiuroidea-larvae
# ✅ Finished copying contents from data/WMR/euphausiidae to data/DETAILED_merged/Crustacea_Euphausidae
# ✅ Finished copying contents from data/WMR/euphausiidae-larvae to data/DETAILED_merged/Crustacea_Euphausidae
# ✅ Finished copying contents from data/WMR/fish-eggs to data/DETAILED_merged/Fish-eggs
# ✅ Finished copying contents from data/WMR/fish-larvae to data/DETAILED_merged/Fish-larvae
# ✅ Finished copying contents from data/WMR/fish-scale to data/DETAILED_merged/Detritus
# ✅ Finished copying contents from data/WMR/fytoplankton_phaeocystis to data/DETAILED_merged/Haptophyta_Phaeocystales
# ✅ Finished copying contents from data/WMR/hemichordata_enteropneusta-tornaria to data/DETAILED_merged/Hemichordata_Enteropneusta-larvae
# ✅ Finished copying contents from data/WMR/larvacea_Friitilaria-complete to data/DETAILED_merged/Larvacea
# ✅ Finished copying contents from data/WMR/larvacea_Oikopleura-complete to data/DETAILED_merged/Larvacea
# ✅ Finished copying contents from data/WMR/larvacea-body to data/DETAILED_merged/Larvacea
# ✅ Finished copying contents from data/WMR/larvacea-tail_only to data/DETAILED_merged/Larvacea
# ✅ Finished copying contents from data/WMR/mollusca_bivalvia-veliger to data/DETAILED_merged/Mollusca_Bivalvia-larvae
# ✅ Finished copying contents from data/WMR/mollusca_gastropoda_Clionidae to data/DETAILED_merged/Gastropoda
# ✅ Finished copying contents from data/WMR/mollusca_gastropoda_Limacina to data/DETAILED_merged/Gastropoda
# ✅ Finished copying contents from data/WMR/mollusca_gastropoda-eggs to data/DETAILED_merged/Invertebrata-eggs
# ✅ Finished copying contents from data/WMR/mollusca_gastropoda-veliger to data/DETAILED_merged/Mollusca_Gastropoda-larvae
# ✅ Finished copying contents from data/WMR/mollusca_scaphopoda-veliger to data/DETAILED_merged/exclude
# ✅ Finished copying contents from data/WMR/multiple_organisms_NOT_USE_FOR_TRAINING to data/DETAILED_merged/exclude
# ✅ Finished copying contents from data/WMR/nemertea_pilidium to data/DETAILED_merged/Nemetrea-larvae
# ✅ Finished copying contents from data/WMR/phoronida-actinotroch to data/DETAILED_merged/Phoronida-larvae
# ✅ Finished copying contents from data/WMR/platyhelminthes_microstomum to data/DETAILED_merged/Platyhelminthes
# ✅ Finished copying contents from data/WMR/platyhelminthes_trematoda-cercariae to data/DETAILED_merged/Platyhelminthes
# ✅ Finished copying contents from data/WMR/polychaete_magelona to data/DETAILED_merged/Annelida_Polychaeta-larvae
# ✅ Finished copying contents from data/WMR/polychaete_Tomopteris to data/DETAILED_merged/Annelida_Polychaeta_Tomopteris
# ✅ Finished copying contents from data/WMR/polychaete-aulophore to data/DETAILED_merged/Annelida_Polychaeta-larvae
# ✅ Finished copying contents from data/WMR/polychaete-empty_tube to data/DETAILED_merged/Detritus
# ✅ Finished copying contents from data/WMR/polychaete-mitraria to data/DETAILED_merged/Annelida_Polychaeta-larvae
# ✅ Finished copying contents from data/WMR/polychaete-nectochaete to data/DETAILED_merged/Annelida_Polychaeta-larvae
# ✅ Finished copying contents from data/WMR/polychaete-nectosoma to data/DETAILED_merged/Annelida_Polychaeta-larvae
# ✅ Finished copying contents from data/WMR/polychaete-trochophore to data/DETAILED_merged/Annelida_Polychaeta-larvae
# ✅ Finished copying contents from data/WMR/radiolaria to data/DETAILED_merged/Radiozoa
# ✅ Finished copying contents from data/WMR/tunicata_dolioloda to data/DETAILED_merged/Tunicata_Doliolida
# ✅ Finished copying contents from data/WMR/unknown_other to data/DETAILED_merged/exclude
# ✅ Finished copying contents from data/WMR/unknown_spherical to data/DETAILED_merged/exclude
# CPU times: user 14.4 s, sys: 1min 17s, total: 1min 31s
# Wall time: 15min 9s
