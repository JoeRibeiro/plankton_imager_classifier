# %% [markdown]
# # Restructure data using key
#
# This code processes images, provided by class in seperate folders, by two institutes (CEFAS & WMR). The images in the folders are moved to new folders, sometimes merged, following a csv file (the "key" file) provided by the researchers.

# %%
# import modules

import pandas as pd
import os
import shutil
from pathlib import Path

# %%
# Read the CSV file
df = pd.read_csv("data/OSPAR_key.csv")
df.head()
# Out:
#                           folder detailed_cat Source  \
# 0        artefact_cleaning_fibre    artefacts    WMR
# 1             artefact_long_line    artefacts    WMR
# 2                     nt-bubbles      bubbles  CEFAS
# 3                        bubbles      bubbles    WMR
# 4  copepod_calanoida_acartia-spp     copepods  CEFAS
#
#                            check  check2
# 0        artefact_cleaning_fibre       0
# 1             artefact_long_line       0
# 2                     nt-bubbles       0
# 3                        bubbles       0
# 4  copepod_calanoida_acartia-spp       0

# %%
# Define the path for the merged folder inside the 'data' directory
merged_dir = Path("data") / "OSPAR_merged"

# Create the directories if they don't exist
merged_dir.mkdir(parents=True, exist_ok=True)

print(f"'merged' folder created at: {merged_dir.resolve()}")
# Out:
# 'merged' folder created at: /lustre/backup/WUR/WMR/hoeke007/Project003c_Plankton_imager_03/data/OSPAR_merged

# %%
# OPTIONAL: Delete folder

# Check if it exists, then delete
#if merged_dir.exists():
#    shutil.rmtree(merged_dir)
#    print(f"Deleted folder: {merged_dir.resolve()}")
#else:
#    print(f"Folder not found: {merged_dir.resolve()}")

# %%
# %%time

# Loop through each row in the DataFrame
for idx, row in df.iterrows():
    # Get the source base path and folder name
    source_base = Path(row["Source"])
    folder_name = row["folder"]
    category = row["detailed_cat"]

    # Full path to the source folder: Source/folder
    source_folder = "data" / source_base / folder_name

    # Full destination path: data/OSPAR_merged/detailed_cat
    dest_folder = Path("data") / "OSPAR_merged" / category

    # Create destination folder if it doesn't exist
    dest_folder.mkdir(parents=True, exist_ok=True)

    # Check if the source folder exists before attempting to copy
    if not source_folder.exists():
        print(f"❌ Source folder does not exist: {source_folder}")
        continue  # Skip this row if the source doesn't exist

    # Iterate over the contents of the source folder
    for item in source_folder.iterdir():
        # Destination path for the current item
        dest_path = dest_folder / item.name

        # If a file or folder with the same name already exists in destination
        if dest_path.exists():
            print(f"⚠️ File already exists, skipping: {dest_path}")
        else:
            # Copy folders (recursively) or files accordingly
            if item.is_dir():
                shutil.copytree(item, dest_path)
            else:
                shutil.copy2(item, dest_path)

    print(f"✅ Finished copying contents from {source_folder} to {dest_folder}")
# Out:
# ✅ Finished copying contents from data/WMR/artefact_cleaning_fibre to data/OSPAR_merged/artefacts
# ✅ Finished copying contents from data/WMR/artefact_long_line to data/OSPAR_merged/artefacts
# ✅ Finished copying contents from data/CEFAS/nt-bubbles to data/OSPAR_merged/bubbles
# ✅ Finished copying contents from data/WMR/bubbles to data/OSPAR_merged/bubbles
# ✅ Finished copying contents from data/CEFAS/copepod_calanoida_acartia-spp to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_calanoida_calanus-spp to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_calanoida_centropages-spp to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_calanoida_temora-spp to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_cyclopoida_oithona-spp to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_cyclopoida_oncaea-spp to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_harpacticoida_euterpina to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_harpacticoida_microstella to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_nauplii to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/WMR/crustacea_copepoda to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/WMR/crustacea_copepoda_monstrilloidae to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/WMR/crustacea_copepoda_nauplii to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/WMR/crustacea_copepoda-epibionts to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_unsorted to data/OSPAR_merged/copepods
# ✅ Finished copying contents from data/CEFAS/copepod_moults to data/OSPAR_merged/detritus
# ✅ Finished copying contents from data/CEFAS/detritus to data/OSPAR_merged/detritus
# ✅ Finished copying contents from data/WMR/crustacea-exuvium to data/OSPAR_merged/detritus
# ✅ Finished copying contents from data/WMR/detritus to data/OSPAR_merged/detritus
# ✅ Finished copying contents from data/CEFAS/Phyto_Centrics to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Chaetoceros to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Coscinodiscus to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Guinardia-flaccida to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Lauderia to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Odontella to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Pleurosigmataceae to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Proboscia-truncata to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Rhizosolenia to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Thalassiosira to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Triceratium to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Trigonium-alternans to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/WMR/diatom_odontella to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/WMR/diatom-loop to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/WMR/diatom-other to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/WMR/diatom-setae to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/WMR/diatom-solitary_centric to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/WMR/diatom-straight to data/OSPAR_merged/diatoms
# ✅ Finished copying contents from data/CEFAS/Phyto_Noctiluca to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/CEFAS/Phyto_Protoperidinium to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos-lineatus to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos-macroceros group to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos-platycorne to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/CEFAS/Phyto_Tripos-tripos group to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/WMR/dinoflagellate_noctiluca-fragment to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/WMR/dinoflagellate_noctiluca-intact to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/WMR/dinoflagellate_pyrocystis to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/WMR/dinoflagellate_Tripos to data/OSPAR_merged/dinoflagellates
# ✅ Finished copying contents from data/CEFAS/ciliophora_suctoria to data/OSPAR_merged/exclude
# ✅ Finished copying contents from data/CEFAS/gastropoda to data/OSPAR_merged/exclude
# ✅ Finished copying contents from data/WMR/multiple_organisms_NOT_USE_FOR_TRAINING to data/OSPAR_merged/exclude
# ✅ Finished copying contents from data/WMR/unknown_other to data/OSPAR_merged/exclude
# ✅ Finished copying contents from data/WMR/unknown_spherical to data/OSPAR_merged/exclude
# ✅ Finished copying contents from data/WMR/fish-eggs to data/OSPAR_merged/fish_eggs
# ✅ Finished copying contents from data/CEFAS/fish-larvae_clupeidae to data/OSPAR_merged/fish_larvae
# ✅ Finished copying contents from data/WMR/fish-larvae to data/OSPAR_merged/fish_larvae
# ✅ Finished copying contents from data/CEFAS/cnidaria_hydrozoa_polyp to data/OSPAR_merged/gelatinous
# ✅ Finished copying contents from data/CEFAS/cnidaria_hydrozoa-hydromedusa to data/OSPAR_merged/gelatinous
# ✅ Finished copying contents from data/WMR/cnidaria_hydrozoa_siphonophora to data/OSPAR_merged/gelatinous
# ✅ Finished copying contents from data/WMR/cnidaria_hydrozoa-hydromedusa to data/OSPAR_merged/gelatinous
# ✅ Finished copying contents from data/WMR/cnidaria_hydrozoa-hydropolyp to data/OSPAR_merged/gelatinous
# ✅ Finished copying contents from data/WMR/cnidaria_scyphozoa-ephyrae to data/OSPAR_merged/gelatinous
# ✅ Finished copying contents from data/WMR/cnidaria-tentacle to data/OSPAR_merged/gelatinous
# ✅ Finished copying contents from data/CEFAS/appendicularia to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/CEFAS/chaetognatha to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/CEFAS/euphausiid_nauplii to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/CEFAS/Podon to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/CEFAS/tintinnida to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/chaetognath to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/cladocera_evadne to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/cladocera_penilia to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/cladocera_podon_pleopis to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/crustacea_mysida to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/ctenophora to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/euphausiidae to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/euphausiidae-larvae to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/larvacea_Friitilaria-complete to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/larvacea_Oikopleura-complete to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/larvacea-body to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/larvacea-tail_only to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/mollusca_gastropoda_Clionidae to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/mollusca_gastropoda_Limacina to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/platyhelminthes_microstomum to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/polychaete_Tomopteris to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/WMR/tunicata_dolioloda to data/OSPAR_merged/holoplankton
# ✅ Finished copying contents from data/CEFAS/amphipoda_caprellidae to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/CEFAS/bivalvia_larvae to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/CEFAS/brachiopoda_larvae to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/CEFAS/branchiostomatidae to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/CEFAS/cirripedia_barnacle_cyprid to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/CEFAS/decapoda-larvae_brachyura to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/CEFAS/echniodermata-larvae to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/CEFAS/invertabrate_eggs to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/amphioxus-larva to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/balanoid-cypris to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/balanoid-nauplius to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/bryozoa-cyphonautes to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/chordata_tunicata-tadpole_larva to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/crustacea_amphipoda to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/crustacea_caprella to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/crustacea_megalopa to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/crustacea_porcellanidae-zoea to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/crustacea-zoea_crab to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/crustacea-zoea_shrimp to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/cumacea to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinodermata_asteroidea_Luidia-Branchiolaria to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinodermata-echinopluteus_type_3 to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinodermata-ophiopluteus_type_2 to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinoderm-bipinnaria to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinoderm-branchiolaria to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinoderm-echinopluteus_type_1 to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinoderm-echinopluteus_type_2 to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinoderm-ophiopluteus_type_1 to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinoderm-stars_asteridae to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinoderm-stars_echino to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/echinoderm-stars_ophio to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/hemichordata_enteropneusta-tornaria to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/mollusca_bivalvia-veliger to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/mollusca_gastropoda-eggs to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/mollusca_gastropoda-veliger to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/mollusca_scaphopoda-veliger to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/nemertea_pilidium to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/phoronida-actinotroch to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/platyhelminthes_trematoda-cercariae to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/polychaete_magelona to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/polychaete-aulophore to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/polychaete-empty_tube to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/polychaete-mitraria to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/polychaete-nectochaete to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/polychaete-nectosoma to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/polychaete-trochophore to data/OSPAR_merged/meroplankton
# ✅ Finished copying contents from data/WMR/fish-scale to data/OSPAR_merged/detritus
# ✅ Finished copying contents from data/CEFAS/radiolaria to data/OSPAR_merged/phytoplankton_other
# ✅ Finished copying contents from data/WMR/cyanobacteria_trichodesmium to data/OSPAR_merged/phytoplankton_other
# ✅ Finished copying contents from data/WMR/fytoplankton_phaeocystis to data/OSPAR_merged/phytoplankton_other
# ✅ Finished copying contents from data/WMR/radiolaria to data/OSPAR_merged/phytoplankton_other
# CPU times: user 9.86 s, sys: 49.1 s, total: 58.9 s
# Wall time: 5min 30s
